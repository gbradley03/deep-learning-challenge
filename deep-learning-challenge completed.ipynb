# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(['EIN', 'NAME'], axis=1, inplace=True)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
app_cat = application_df.dtypes.index.tolist()
application_df[app_cat].nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_count = application_df['APPLICATION_TYPE'].value_counts()
app_type_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_type_count[app_type_count < 600].index)
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_count = application_df['CLASSIFICATION'].value_counts()
class_count.head(20)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# Name: CLASSIFICATION, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1278       10
# C1238       10
# C1237        9
# C1235        9
# C7210        7
# C1720        6
# C2400        6
# C4100        6
# C1257        5
# C1600        5
# C0           3
# C1260        3
# C2710        3
# C1234        2
# C1246        2
# C1267        2
# C3200        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_count[class_count < 300].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric_app_df = pd.get_dummies(application_df)
numeric_app_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       1
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                         0                    0                    0
# 1                         0                    1                    0
# 2                         0                    0                    0
# 3                         0                    1                    0
# 4                         0                    1                    0
# ...                     ...                  ...                  ...
# 34294                     0                    0                    1
# 34295                     0                    0                    1
# 34296                     0                    1                    0
# 34297                     0                    0                    0
# 34298                     0                    1                    0
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        1                    0                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    0                    0                    0  ...
# 34295                    0                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    1                    0                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = numeric_app_df["IS_SUCCESSFUL"]
X = numeric_app_df.drop(["IS_SUCCESSFUL"],axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 9
hidden_nodes_layer2 = 18

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 396
#
#  dense_1 (Dense)             (None, 18)                180
#
#  dense_2 (Dense)             (None, 1)                 19
#
# =================================================================
# Total params: 595
# Trainable params: 595
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 937us/step - loss: 0.5872 - accuracy: 0.7130
# Epoch 2/100
# 804/804 [==============================] - 1s 809us/step - loss: 0.5593 - accuracy: 0.7289
# Epoch 3/100
# 804/804 [==============================] - 1s 811us/step - loss: 0.5550 - accuracy: 0.7301
# Epoch 4/100
# 804/804 [==============================] - 1s 793us/step - loss: 0.5526 - accuracy: 0.7323
# Epoch 5/100
# 804/804 [==============================] - 1s 836us/step - loss: 0.5514 - accuracy: 0.7308
# Epoch 6/100
# 804/804 [==============================] - 1s 816us/step - loss: 0.5507 - accuracy: 0.7308
# Epoch 7/100
# 804/804 [==============================] - 1s 794us/step - loss: 0.5496 - accuracy: 0.7318
# Epoch 8/100
# 804/804 [==============================] - 1s 798us/step - loss: 0.5491 - accuracy: 0.7331
# Epoch 9/100
# 804/804 [==============================] - 1s 812us/step - loss: 0.5487 - accuracy: 0.7332
# Epoch 10/100
# 804/804 [==============================] - 1s 798us/step - loss: 0.5483 - accuracy: 0.7320
# Epoch 11/100
# 804/804 [==============================] - 1s 803us/step - loss: 0.5482 - accuracy: 0.7321
# Epoch 12/100
# 804/804 [==============================] - 1s 839us/step - loss: 0.5476 - accuracy: 0.7323
# Epoch 13/100
# 804/804 [==============================] - 1s 755us/step - loss: 0.5472 - accuracy: 0.7337
# Epoch 14/100
# 804/804 [==============================] - 1s 757us/step - loss: 0.5474 - accuracy: 0.7326
# Epoch 15/100
# 804/804 [==============================] - 1s 762us/step - loss: 0.5467 - accuracy: 0.7333
# Epoch 16/100
# 804/804 [==============================] - 1s 823us/step - loss: 0.5469 - accuracy: 0.7322
# Epoch 17/100
# 804/804 [==============================] - 1s 801us/step - loss: 0.5466 - accuracy: 0.7338
# Epoch 18/100
# 804/804 [==============================] - 1s 836us/step - loss: 0.5464 - accuracy: 0.7336
# Epoch 19/100
# 804/804 [==============================] - 1s 792us/step - loss: 0.5461 - accuracy: 0.7334
# Epoch 20/100
# 804/804 [==============================] - 1s 783us/step - loss: 0.5460 - accuracy: 0.7336
# Epoch 21/100
# 804/804 [==============================] - 1s 772us/step - loss: 0.5462 - accuracy: 0.7325
# Epoch 22/100
# 804/804 [==============================] - 1s 747us/step - loss: 0.5458 - accuracy: 0.7338
# Epoch 23/100
# 804/804 [==============================] - 1s 749us/step - loss: 0.5458 - accuracy: 0.7332
# Epoch 24/100
# 804/804 [==============================] - 1s 748us/step - loss: 0.5456 - accuracy: 0.7332
# Epoch 25/100
# 804/804 [==============================] - 1s 749us/step - loss: 0.5457 - accuracy: 0.7340
# Epoch 26/100
# 804/804 [==============================] - 1s 748us/step - loss: 0.5450 - accuracy: 0.7343
# Epoch 27/100
# 804/804 [==============================] - 1s 790us/step - loss: 0.5450 - accuracy: 0.7341
# Epoch 28/100
# 804/804 [==============================] - 1s 749us/step - loss: 0.5447 - accuracy: 0.7329
# Epoch 29/100
# 804/804 [==============================] - 1s 748us/step - loss: 0.5451 - accuracy: 0.7331
# Epoch 30/100
# 804/804 [==============================] - 1s 787us/step - loss: 0.5449 - accuracy: 0.7345
# Epoch 31/100
# 804/804 [==============================] - 1s 782us/step - loss: 0.5446 - accuracy: 0.7336
# Epoch 32/100
# 804/804 [==============================] - 1s 798us/step - loss: 0.5446 - accuracy: 0.7332
# Epoch 33/100
# 804/804 [==============================] - 1s 809us/step - loss: 0.5445 - accuracy: 0.7344
# Epoch 34/100
# 804/804 [==============================] - 1s 834us/step - loss: 0.5446 - accuracy: 0.7336
# Epoch 35/100
# 804/804 [==============================] - 1s 773us/step - loss: 0.5444 - accuracy: 0.7345
# Epoch 36/100
# 804/804 [==============================] - 1s 790us/step - loss: 0.5447 - accuracy: 0.7340
# Epoch 37/100
# 804/804 [==============================] - 1s 765us/step - loss: 0.5440 - accuracy: 0.7339
# Epoch 38/100
# 804/804 [==============================] - 1s 813us/step - loss: 0.5440 - accuracy: 0.7347
# Epoch 39/100
# 804/804 [==============================] - 1s 757us/step - loss: 0.5443 - accuracy: 0.7346
# Epoch 40/100
# 804/804 [==============================] - 1s 779us/step - loss: 0.5442 - accuracy: 0.7345
# Epoch 41/100
# 804/804 [==============================] - 1s 773us/step - loss: 0.5437 - accuracy: 0.7357
# Epoch 42/100
# 804/804 [==============================] - 1s 796us/step - loss: 0.5438 - accuracy: 0.7341
# Epoch 43/100
# 804/804 [==============================] - 1s 791us/step - loss: 0.5437 - accuracy: 0.7353
# Epoch 44/100
# 804/804 [==============================] - 1s 798us/step - loss: 0.5437 - accuracy: 0.7351
# Epoch 45/100
# 804/804 [==============================] - 1s 794us/step - loss: 0.5436 - accuracy: 0.7350
# Epoch 46/100
# 804/804 [==============================] - 1s 821us/step - loss: 0.5434 - accuracy: 0.7343
# Epoch 47/100
# 804/804 [==============================] - 1s 770us/step - loss: 0.5438 - accuracy: 0.7350
# Epoch 48/100
# 804/804 [==============================] - 1s 769us/step - loss: 0.5436 - accuracy: 0.7358
# Epoch 49/100
# 804/804 [==============================] - 1s 765us/step - loss: 0.5437 - accuracy: 0.7349
# Epoch 50/100
# 804/804 [==============================] - 1s 785us/step - loss: 0.5435 - accuracy: 0.7355
# Epoch 51/100
# 804/804 [==============================] - 1s 797us/step - loss: 0.5436 - accuracy: 0.7342
# Epoch 52/100
# 804/804 [==============================] - 1s 783us/step - loss: 0.5429 - accuracy: 0.7345
# Epoch 53/100
# 804/804 [==============================] - 1s 876us/step - loss: 0.5433 - accuracy: 0.7351
# Epoch 54/100
# 804/804 [==============================] - 1s 790us/step - loss: 0.5436 - accuracy: 0.7348
# Epoch 55/100
# 804/804 [==============================] - 1s 762us/step - loss: 0.5434 - accuracy: 0.7351
# Epoch 56/100
# 804/804 [==============================] - 1s 739us/step - loss: 0.5434 - accuracy: 0.7354
# Epoch 57/100
# 804/804 [==============================] - 1s 744us/step - loss: 0.5432 - accuracy: 0.7357
# Epoch 58/100
# 804/804 [==============================] - 1s 778us/step - loss: 0.5432 - accuracy: 0.7357
# Epoch 59/100
# 804/804 [==============================] - 1s 774us/step - loss: 0.5433 - accuracy: 0.7358
# Epoch 60/100
# 804/804 [==============================] - 1s 767us/step - loss: 0.5432 - accuracy: 0.7348
# Epoch 61/100
# 804/804 [==============================] - 1s 755us/step - loss: 0.5431 - accuracy: 0.7355
# Epoch 62/100
# 804/804 [==============================] - 1s 746us/step - loss: 0.5430 - accuracy: 0.7355
# Epoch 63/100
# 804/804 [==============================] - 1s 796us/step - loss: 0.5427 - accuracy: 0.7363
# Epoch 64/100
# 804/804 [==============================] - 1s 795us/step - loss: 0.5426 - accuracy: 0.7353
# Epoch 65/100
# 804/804 [==============================] - 1s 859us/step - loss: 0.5429 - accuracy: 0.7363
# Epoch 66/100
# 804/804 [==============================] - 1s 883us/step - loss: 0.5427 - accuracy: 0.7355
# Epoch 67/100
# 804/804 [==============================] - 1s 877us/step - loss: 0.5428 - accuracy: 0.7353
# Epoch 68/100
# 804/804 [==============================] - 1s 826us/step - loss: 0.5428 - accuracy: 0.7345
# Epoch 69/100
# 804/804 [==============================] - 1s 794us/step - loss: 0.5428 - accuracy: 0.7367
# Epoch 70/100
# 804/804 [==============================] - 1s 811us/step - loss: 0.5427 - accuracy: 0.7348
# Epoch 71/100
# 804/804 [==============================] - 1s 798us/step - loss: 0.5424 - accuracy: 0.7374
# Epoch 72/100
# 804/804 [==============================] - 1s 796us/step - loss: 0.5426 - accuracy: 0.7360
# Epoch 73/100
# 804/804 [==============================] - 1s 793us/step - loss: 0.5423 - accuracy: 0.7367
# Epoch 74/100
# 804/804 [==============================] - 1s 837us/step - loss: 0.5426 - accuracy: 0.7356
# Epoch 75/100
# 804/804 [==============================] - 1s 817us/step - loss: 0.5424 - accuracy: 0.7365
# Epoch 76/100
# 804/804 [==============================] - 1s 792us/step - loss: 0.5423 - accuracy: 0.7369
# Epoch 77/100
# 804/804 [==============================] - 1s 770us/step - loss: 0.5424 - accuracy: 0.7355
# Epoch 78/100
# 804/804 [==============================] - 1s 775us/step - loss: 0.5425 - accuracy: 0.7358
# Epoch 79/100
# 804/804 [==============================] - 1s 767us/step - loss: 0.5424 - accuracy: 0.7369
# Epoch 80/100
# 804/804 [==============================] - 1s 760us/step - loss: 0.5424 - accuracy: 0.7371
# Epoch 81/100
# 804/804 [==============================] - 1s 774us/step - loss: 0.5426 - accuracy: 0.7366
# Epoch 82/100
# 804/804 [==============================] - 1s 805us/step - loss: 0.5422 - accuracy: 0.7362
# Epoch 83/100
# 804/804 [==============================] - 1s 811us/step - loss: 0.5428 - accuracy: 0.7351
# Epoch 84/100
# 804/804 [==============================] - 1s 839us/step - loss: 0.5421 - accuracy: 0.7370
# Epoch 85/100
# 804/804 [==============================] - 1s 844us/step - loss: 0.5421 - accuracy: 0.7363
# Epoch 86/100
# 804/804 [==============================] - 1s 779us/step - loss: 0.5420 - accuracy: 0.7367
# Epoch 87/100
# 804/804 [==============================] - 1s 773us/step - loss: 0.5421 - accuracy: 0.7356
# Epoch 88/100
# 804/804 [==============================] - 1s 818us/step - loss: 0.5420 - accuracy: 0.7366
# Epoch 89/100
# 804/804 [==============================] - 1s 800us/step - loss: 0.5421 - accuracy: 0.7360
# Epoch 90/100
# 804/804 [==============================] - 1s 780us/step - loss: 0.5418 - accuracy: 0.7366
# Epoch 91/100
# 804/804 [==============================] - 1s 799us/step - loss: 0.5420 - accuracy: 0.7368
# Epoch 92/100
# 804/804 [==============================] - 1s 798us/step - loss: 0.5421 - accuracy: 0.7360
# Epoch 93/100
# 804/804 [==============================] - 1s 833us/step - loss: 0.5420 - accuracy: 0.7364
# Epoch 94/100
# 804/804 [==============================] - 1s 815us/step - loss: 0.5418 - accuracy: 0.7360
# Epoch 95/100
# 804/804 [==============================] - 1s 877us/step - loss: 0.5418 - accuracy: 0.7369
# Epoch 96/100
# 804/804 [==============================] - 1s 884us/step - loss: 0.5422 - accuracy: 0.7365
# Epoch 97/100
# 804/804 [==============================] - 1s 836us/step - loss: 0.5420 - accuracy: 0.7370
# Epoch 98/100
# 804/804 [==============================] - 1s 843us/step - loss: 0.5418 - accuracy: 0.7364
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5417 - accuracy: 0.7374
# Epoch 100/100
# 804/804 [==============================] - 1s 894us/step - loss: 0.5418 - accuracy: 0.7365

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5510 - accuracy: 0.7250 - 251ms/epoch - 935us/step
# Loss: 0.5509687066078186, Accuracy: 0.7250145673751831

# %%
# plotting the accuracy
history_df = pd.DataFrame(fit_model.history, index = range(1, len(fit_model.history['loss'])+1))
history_df.plot(y = 'accuracy')
# Out:
# <AxesSubplot:>

# %%
# Export our model to HDF5 file
nn.save('Models/AlphabetSoupCharity1.h5')

# %% [markdown]
# RESULTS:
#
# APPLICATION_TYPE cutoff = 600
# CLASSIFICATION cutoff = 300
# layer1 = 9 : activation function = relu
# layer2 = 18 : activation function = relu
#
# Loss: 0.5536191259042167, Accuracy: 0.727580189704895
#
# A loss value of 55 indicates that the model can be further optimized.
# The accuracy percent shows that 72% of the model's predicted values align with the true values in the original dataset.
#
# I need to make some changes in order to get to 75% accuracy.
#
# I also ran the following variables through this model:
#
#
# APPLICATION_TYPE cutoff = 600
# CLASSIFICATION cutoff = 300
# layer1 = 12
# layer2 = 24
#
# Loss: 0.5522796763553564, Accuracy: 0.7250145673751831
#
#
# APPLICATION_TYPE cutoff = 800
# CLASSIFICATION cutoff = 1000
# layer1 = 12
# layer2 = 24
#
# Loss: 0.5575985619278065, Accuracy: 0.7231487035751343
